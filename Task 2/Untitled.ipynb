# %%
import re


#讀取檔案，並回傳 raw list
def inputList():
    with open('bi_xu_raw.txt', 'r') as fh:
        #刪去整個txt檔中的\n\t，並以'more'區分
        raw = fh.read().replace('\n', '').replace('\t', '').split('more')
    return raw
        
def process(raw):
    processed = []
    for line in raw:
        if "必須" in line:
            p = "。,，！？；"
            pattern = f"([^{p}]*必須[^{p}]*)"
            matches = re.findall(pattern, line)
            for match in matches:
                processed.append(match)
    processed = list(set(processed))
    return processed

#呈現processed list
def show(processed):
    for s in processed:
        print(f'{s}')

#將processed list輸出txt檔
def save(processed):
    with open('bi_xu_processed.txt', 'w') as fh:
        sentence = [f'{s}\n' for s in processed]
        fh.writelines(sentence)
        

                

raw_list = inputList()
processed_list = process(raw_list)
show(processed_list)
save(processed_list)
# Out:
# 他必須壓抑暗戀同事、有找不到朋友的苦悶情緒
# 「必須制訂新戰略來服務總體戰略
# 三、採集和貯存設備品質必須獲得確認
# 必須重新申請
# 高爾夫必須同時與一百多位選手競爭
# 成為FLA的代理檢查者必須具備中立性與獨立性
# 一、必須確保臍帶血採集和保存技術的品質
# 重考生必須回原畢業學校領取
# 必須加蓋學校證明章或查證人員職章
# 必須與國外具有相關合作經驗的廠商合作才能符合資格標
# 必須再等上十年
# 都必須放在整個世界格局中考量
# 必須全部申報
# 但必須一步步為合併鋪路
# 專利案申請內容必須經過十八個月的公開期
# 我方必須先了解實情是否和報導有出入
# 必須採取其他配套措施降低振動干擾
# 必須課贈與稅
# 就必須立刻從戴高樂機場轉機離開
# 但地方政府也必須開始「長大」
# 李進枝認為林女取得股票必須與他同居
# 市府必須掌握在手中
# 日本政府必須宣佈一個讓國民及輿論、國際社會能接受的解決方案
# 但又必須發洩隱藏的情慾
# 且必須保持低調
# 吳雨水確因工作環境必須長期暴露於硫酸氣體中
# 台電必須再深入調查
# 依法必須先取得該局核發之製造業者許可執照
# 則退休金提撥率必須要到八％到九％之間
# 姐弟倆必須自己打理日常所需
# 必須要在正式營運時
# 但必須製劑每一百毫升含量五公克以上
# 警方必須依法追究其刑責
# 未來制度設計時必須加以注意
# 因此學者建議必須將該協調會議的組成代表明訂在法律當中
# 也必須考慮在地人的觀感
# 必須像是很自然地從地上長出來的物件
# 必須慎重思考
# 台北市版規定未滿十五歲以下必須由父母陪同才能進入
# 台北縣用水必須向台北市買水
# 必須以更積極的總經政策來因應
# 兩岸之間必須透過半官方的海基會、海協會接觸
# 必須移送強制觀察勒戒或強制戒治
# 必須先將一整年的行事曆公告出來
# 我必須要作對的事
# 政府必須分年編列預算軋平
# 必須強制拆除
# 也必須同時付出更多的努力去維護人性的尊嚴、保存共享的社群
# 而此事必須獲得中共方面的協助
# 屬藥品管理的產品必須依醫師指示或處方使用
# 不過必須考慮民、親兩黨支持者態度
# 等於Ｐ４必須肩負起平均四至五成的出貨比重
# 必須把腫瘤拿出體外
# 以及台灣高鐵必須與工程承包商重新議約
# 由於學校方面認為在租賃國宅後必須添購相關設備
# 必須賠償對方家屬一百多萬元
# 這三人必須到九十二年二月以後
# 我們必須要真正觸及這些貧苦的人民
# 必須利用公車前往
# 當初承諾必須配合股本的增加
# 未來只有三十人以上的事業單位必須受這項法案規範
# 必須注意配銷系統、加強衛生基礎設施並注重品管
# 但前晚田弘茂突然報告總統自己必須前往馬其頓處理
# 也必須每年提升股本
# 不過整個法案必須經由眾議院院會通過
# 因為該批本土派立委必須以脫離國
# 我們必須先了解
# 他們就必須先搭設簡便的工寮及營區
# 必須先向主任檢察官、檢察長提出報告
# 仍限定必須以間接方式為之
# 而比照九二一震災則必須等立法院提案通過
# 不僅害得她及大姊必須放棄升學的心願
# 若取得標案後還必須進行增資
# 、採集和貯存設備品質必須獲得確認
# 必須更誠實地處理台灣可能面臨的不利形勢
# 要求該公司必須處理
# 十月起必須設置資源回收設施
# 則要求必須符合聯合國憲章
# 必須拉高思考層次
# 土派立委必須以脫離國民黨為前提
# 明年中央和地方教育總經費必須達四千兩百四十三億元
# 中共必須維持和平與人權形象
# 依慣例必須在國中生入學前即定案宣布
# 惟民眾必須在回收場的作業時間內自行將資源垃圾運送至回收場
# 勞工必須工作滿三十年
# 也必須削減成本
# 保護區內的建築物高度必須是七公尺以下的二層樓
# 也難怪英特爾必須加快加速Ｐ４降價動作
# 必須尋求減少對美國出口與電子裝配的依賴
# 就是必須能夠讓她覺得感動
# 面對部分人士要求金融機構必須大開貸放之門
# 未來必須在政策面決定是否對目前經評估認為不適合人居的地方進
# 必須自行應徵學校任教
# 強調各國領袖必須對反恐發出強烈明確的訊息
# 我們必須要
# 台灣必須在這問題上保持高度的靈活與彈性
# 教育局過去之年度賸餘預算必須繳庫
# 因此依規定必須在六月底前
# 因此必須在愛滋病藥普及前作好準備
# 但是必須觀察景氣領先指標連續三個月都是上升情勢後
# 代表團的行程因此必須延後一天
# 們必須要正視貧苦大眾遭野心政客非法利用的問題
# 明定市話業者必須提供用戶選接第二類業者網路的義務
# 因為該批本土派立委必須以脫離國民黨為前提
# 必須先勘察地形
# 開車禁用手持式大哥大」與「汽車駕駛及前座乘客行車時必須繫安全帶」兩項新的交通法規
# 就必須面對所謂的「空巢症候群」
# 也必須透過法院移轉給學校法人
# 必須接受洗腎治療
# 海外私梟必須輾轉透過該幫才能取得貨源
# 必須進行重大憲政改造
# 總統必須交出組閣權
# 因此要求國華必須辦理三十億元的現金增資案
# 醫院認為必須住院觀察
# 穆夏拉夫的訴求是新阿富汗必須民主、合法、種族平衡
# 這項實績費率制使職災愈高的雇主必須負擔愈高的保費
# 係必須辦理市地重劃始得開發之地
# 必須先向高檢署報告
# 往往必須仰賴各項評鑑與報導
# 不過這項措施必須由政府先協助解決年資結算金不足的一百八十七億元
# 屆時必須再修正延長施行期限
# 必須再有配套的措施
# 這個問題必須要來做
# 合議庭卅日判決江某和其雇主尚等實業公司必須連帶賠償已經陽痿的林某新台幣一千七百七十萬多元
# 許多路段必須用手攀爬通過
# 回收點必須在入口明顯處標示回收點標
# 另一個必須考慮的是時脈與整體效能
# 必須由檢察機關查明真相
# 捷運公司必須支付租金
# 同時必須說明目的與指定用途
# 必須重新思考水資源的管理問題
# 您也必須下定決心停用
# 各亞洲國家政府必須採取更嚴格的經濟改革
# 他必須到九十年十月以後才可提出假釋申請
# 最重要的是彼此理念必須要相近
# 血壓必須由強力血管收縮劑維持
# 將來北銀若因故必須更換合作廠商也不至於發生無法解決的問題
# 卻是各業者必須克服的難題
# 必須對反恐怖主義表達清晰強烈的訊息
# 但必須格外謹慎小心
# 家長除了必須了解孩子
# 可能就必須考慮陳朝興的建議
# 執政黨必須執行在野黨的立法
# 必須等到投票日前一周
# 導致其他國家必須付出較高的進口食物到貧窮國家的代價
# 會長必須具備會員資格一年以上
# 市府必須負起責任
# 必須結合國外知名電信業者
# 四、兩岸關係必須在全球架構下做整體思考
# 必須配合正確的會陰照顧才能達到預期的效果
# 符合拆遷補助費請領資格的建物必須是有門牌者
# 大學籌設必須提出計劃
# 李前總統必須在廿四日前抵達醫院
# 張俊雄認為政府必須正視土石流的問題
# 必須多試幾次
# 而是必須考慮到公平性
# 教育部都必須提出充分的理由
# 必須完成公司內部作業程序
# 名人必須不時更換車輛
# 致使標準普爾必須對所得數據進行必要的調整與推估
# 四、移植臍帶血前必須經過篩檢
# 則勞工所需負擔的費率必須每年調整
# 必須先打老虎
# 我們都必須遵行聯合國的認知原則
# 必須罰款一萬九千五百元
# ＡＰＥＣ部長會議必須在二○○二年部長會議前提出具體的行動措施
# 因此衛生署無法強制業者必須申請認證
# 使得旺宏必須重新規劃及定位晶圓三廠的大手筆投資進度
# 必須配合中央政府各機關硬體設施及軟體運作
# 必須依照「內控」規定處理
# 這些華語導遊人員必須再接受三周的專業訓練
# 對兒女的要求也必須量力而為
# 她更必須勤跑基層
# 土地必須依當初承諾與計劃
# 原本必須二年以上臨床經驗才能夠報考的規定將取消
# 必須陪他同居二年做為抵償
# 必須提出足夠服人的證據和數據
# 必須停在路邊才能使用
# 學生必須眼明腳快
# 查賄必須要有更清楚的定義
# 必須由軍方來決定
# 但又必須在大選時對政府整體施政表現負全責
# 中華電信和新固網業最晚在三月十二日必須開始進行網路互連測試
# 以及必須要完成的事
# 二、必須由專業人員從事臍帶血分離、取得和保存
# 也逐漸成為政府所必須保障的基本人權
# 台積電必須在日本設廠
# 主計處必須進行最後檢討
# 約有廿％的嚴重感染者必須住院治療
# 逼得跑道上一架準備起飛的中國東方航空班機必須緊急煞車
# 必須全面加強各層次、整體的國際反恐怖合作
# 掃除黑金必須先打老虎
# 必須用防火材質設置「避難層」（亦即防火阻絕層）
# 但也必須將新的政治主張列為階段性行動綱領
# 必須立刻就醫
# 我們必須要正視貧苦大眾遭野心政客非法利用的問題
# 必須保有彈性
# 每一家債權銀行都必須遵守
# 政府並協助取得必須的土地
# 必須要肅貪法庭作出決定
# 自治條例草案是根據教育經費編列與管理法有關地方政府必須設置教育發展基金編列預算並制訂相關條例管理而來
# 主要必須藉由建築物本身的消防設備
# 必須出具董事會通過之增資承諾書

# %%
import re

#讀取檔案，並回傳 raw list
def inputList():
    with open('bi_xu_raw.txt', 'r') as fh:
        #刪去整個txt檔中的\n\t，並以'more'區分
        raw = fh.read().replace('\n', '').replace('\t', '').split('more')
    return raw
    
#輸入並處理raw list、回傳processed list
def process(raw):
    processed = []
    for line in raw:
        pattern = '，|。|！|？|；'
        #把每一行依照標點符號(pattern)分成段（類似子句）
        parts = re.split(pattern, line,)
        for part in parts:
            #選取含有"必須"的片段，並append到processed lsit
            if "必須" in part:
                processed.append(part)
    #轉成集合已刪除重複句，再轉回list
    processed = list(set(processed))
    return processed
    
#呈現processed list
def show(processed):
    for s in processed:
        print(f'{s}')

#將processed list輸出txt檔
def save(processed):
    with open('bi_xu_processed.txt', 'w') as fh:
        sentence = [f'{s}\n' for s in processed]
        fh.writelines(sentence)
        

                

raw_list = inputList()
processed_list = process(raw_list)
show(processed_list)
save(processed_list)
# Out:
# 他必須壓抑暗戀同事、有找不到朋友的苦悶情緒
# 「必須制訂新戰略來服務總體戰略
# 三、採集和貯存設備品質必須獲得確認
# 必須重新申請
# 高爾夫必須同時與一百多位選手競爭
# 成為FLA的代理檢查者必須具備中立性與獨立性
# 一、必須確保臍帶血採集和保存技術的品質
# 重考生必須回原畢業學校領取
# 必須加蓋學校證明章或查證人員職章
# 必須與國外具有相關合作經驗的廠商合作才能符合資格標
# 必須再等上十年
# 都必須放在整個世界格局中考量
# 必須全部申報
# 但必須一步步為合併鋪路
# 專利案申請內容必須經過十八個月的公開期
# 我方必須先了解實情是否和報導有出入
# 必須採取其他配套措施降低振動干擾
# 必須課贈與稅
# 就必須立刻從戴高樂機場轉機離開
# 但地方政府也必須開始「長大」
# 李進枝認為林女取得股票必須與他同居
# 市府必須掌握在手中
# 日本政府必須宣佈一個讓國民及輿論、國際社會能接受的解決方案
# 但又必須發洩隱藏的情慾
# 且必須保持低調
# 吳雨水確因工作環境必須長期暴露於硫酸氣體中
# 台電必須再深入調查
# 依法必須先取得該局核發之製造業者許可執照
# 則退休金提撥率必須要到八％到九％之間
# 姐弟倆必須自己打理日常所需
# 必須要在正式營運時
# 但必須製劑每一百毫升含量五公克以上
# 警方必須依法追究其刑責
# 未來制度設計時必須加以注意
# 因此學者建議必須將該協調會議的組成代表明訂在法律當中
# 也必須考慮在地人的觀感
# 必須像是很自然地從地上長出來的物件
# 必須慎重思考
# 台北市版規定未滿十五歲以下必須由父母陪同才能進入
# 台北縣用水必須向台北市買水
# 必須以更積極的總經政策來因應
# 兩岸之間必須透過半官方的海基會、海協會接觸
# 必須移送強制觀察勒戒或強制戒治
# 必須先將一整年的行事曆公告出來
# 我必須要作對的事
# 政府必須分年編列預算軋平
# 必須強制拆除
# 也必須同時付出更多的努力去維護人性的尊嚴、保存共享的社群
# 而此事必須獲得中共方面的協助
# 屬藥品管理的產品必須依醫師指示或處方使用
# 不過必須考慮民、親兩黨支持者態度
# 等於Ｐ４必須肩負起平均四至五成的出貨比重
# 必須把腫瘤拿出體外
# 以及台灣高鐵必須與工程承包商重新議約
# 由於學校方面認為在租賃國宅後必須添購相關設備
# 必須賠償對方家屬一百多萬元
# 這三人必須到九十二年二月以後
# 我們必須要真正觸及這些貧苦的人民
# 必須利用公車前往
# 當初承諾必須配合股本的增加
# 未來只有三十人以上的事業單位必須受這項法案規範
# 必須注意配銷系統、加強衛生基礎設施並注重品管
# 但前晚田弘茂突然報告總統自己必須前往馬其頓處理
# 也必須每年提升股本
# 不過整個法案必須經由眾議院院會通過
# 因為該批本土派立委必須以脫離國
# 我們必須先了解
# 他們就必須先搭設簡便的工寮及營區
# 必須先向主任檢察官、檢察長提出報告
# 仍限定必須以間接方式為之
# 而比照九二一震災則必須等立法院提案通過
# 不僅害得她及大姊必須放棄升學的心願
# 若取得標案後還必須進行增資
# 、採集和貯存設備品質必須獲得確認
# 必須更誠實地處理台灣可能面臨的不利形勢
# 要求該公司必須處理
# 十月起必須設置資源回收設施
# 則要求必須符合聯合國憲章
# 必須拉高思考層次
# 土派立委必須以脫離國民黨為前提
# 明年中央和地方教育總經費必須達四千兩百四十三億元
# 中共必須維持和平與人權形象
# 依慣例必須在國中生入學前即定案宣布
# 惟民眾必須在回收場的作業時間內自行將資源垃圾運送至回收場
# 勞工必須工作滿三十年
# 也必須削減成本
# 保護區內的建築物高度必須是七公尺以下的二層樓
# 也難怪英特爾必須加快加速Ｐ４降價動作
# 必須尋求減少對美國出口與電子裝配的依賴
# 就是必須能夠讓她覺得感動
# 面對部分人士要求金融機構必須大開貸放之門
# 未來必須在政策面決定是否對目前經評估認為不適合人居的地方進
# 必須自行應徵學校任教
# 強調各國領袖必須對反恐發出強烈明確的訊息
# 我們必須要
# 台灣必須在這問題上保持高度的靈活與彈性
# 教育局過去之年度賸餘預算必須繳庫
# 因此依規定必須在六月底前
# 因此必須在愛滋病藥普及前作好準備
# 但是必須觀察景氣領先指標連續三個月都是上升情勢後
# 代表團的行程因此必須延後一天
# 們必須要正視貧苦大眾遭野心政客非法利用的問題
# 明定市話業者必須提供用戶選接第二類業者網路的義務
# 因為該批本土派立委必須以脫離國民黨為前提
# 必須先勘察地形
# 開車禁用手持式大哥大」與「汽車駕駛及前座乘客行車時必須繫安全帶」兩項新的交通法規
# 就必須面對所謂的「空巢症候群」
# 也必須透過法院移轉給學校法人
# 必須接受洗腎治療
# 海外私梟必須輾轉透過該幫才能取得貨源
# 必須進行重大憲政改造
# 總統必須交出組閣權
# 因此要求國華必須辦理三十億元的現金增資案
# 醫院認為必須住院觀察
# 穆夏拉夫的訴求是新阿富汗必須民主、合法、種族平衡
# 這項實績費率制使職災愈高的雇主必須負擔愈高的保費
# 係必須辦理市地重劃始得開發之地
# 必須先向高檢署報告
# 往往必須仰賴各項評鑑與報導
# 不過這項措施必須由政府先協助解決年資結算金不足的一百八十七億元
# 屆時必須再修正延長施行期限
# 必須再有配套的措施
# 這個問題必須要來做
# 合議庭卅日判決江某和其雇主尚等實業公司必須連帶賠償已經陽痿的林某新台幣一千七百七十萬多元
# 許多路段必須用手攀爬通過
# 回收點必須在入口明顯處標示回收點標
# 另一個必須考慮的是時脈與整體效能
# 必須由檢察機關查明真相
# 捷運公司必須支付租金
# 同時必須說明目的與指定用途
# 必須重新思考水資源的管理問題
# 您也必須下定決心停用
# 各亞洲國家政府必須採取更嚴格的經濟改革
# 他必須到九十年十月以後才可提出假釋申請
# 最重要的是彼此理念必須要相近
# 血壓必須由強力血管收縮劑維持
# 將來北銀若因故必須更換合作廠商也不至於發生無法解決的問題
# 卻是各業者必須克服的難題
# 必須對反恐怖主義表達清晰強烈的訊息
# 但必須格外謹慎小心
# 家長除了必須了解孩子
# 可能就必須考慮陳朝興的建議
# 執政黨必須執行在野黨的立法
# 必須等到投票日前一周
# 導致其他國家必須付出較高的進口食物到貧窮國家的代價
# 會長必須具備會員資格一年以上
# 市府必須負起責任
# 必須結合國外知名電信業者
# 四、兩岸關係必須在全球架構下做整體思考
# 必須配合正確的會陰照顧才能達到預期的效果
# 符合拆遷補助費請領資格的建物必須是有門牌者
# 大學籌設必須提出計劃
# 李前總統必須在廿四日前抵達醫院
# 張俊雄認為政府必須正視土石流的問題
# 必須多試幾次
# 而是必須考慮到公平性
# 教育部都必須提出充分的理由
# 必須完成公司內部作業程序
# 名人必須不時更換車輛
# 致使標準普爾必須對所得數據進行必要的調整與推估
# 四、移植臍帶血前必須經過篩檢
# 則勞工所需負擔的費率必須每年調整
# 必須先打老虎
# 我們都必須遵行聯合國的認知原則
# 必須罰款一萬九千五百元
# ＡＰＥＣ部長會議必須在二○○二年部長會議前提出具體的行動措施
# 因此衛生署無法強制業者必須申請認證
# 使得旺宏必須重新規劃及定位晶圓三廠的大手筆投資進度
# 必須配合中央政府各機關硬體設施及軟體運作
# 必須依照「內控」規定處理
# 這些華語導遊人員必須再接受三周的專業訓練
# 對兒女的要求也必須量力而為
# 她更必須勤跑基層
# 土地必須依當初承諾與計劃
# 原本必須二年以上臨床經驗才能夠報考的規定將取消
# 必須陪他同居二年做為抵償
# 必須提出足夠服人的證據和數據
# 必須停在路邊才能使用
# 學生必須眼明腳快
# 查賄必須要有更清楚的定義
# 必須由軍方來決定
# 但又必須在大選時對政府整體施政表現負全責
# 中華電信和新固網業最晚在三月十二日必須開始進行網路互連測試
# 以及必須要完成的事
# 二、必須由專業人員從事臍帶血分離、取得和保存
# 也逐漸成為政府所必須保障的基本人權
# 台積電必須在日本設廠
# 主計處必須進行最後檢討
# 約有廿％的嚴重感染者必須住院治療
# 逼得跑道上一架準備起飛的中國東方航空班機必須緊急煞車
# 必須全面加強各層次、整體的國際反恐怖合作
# 掃除黑金必須先打老虎
# 必須用防火材質設置「避難層」（亦即防火阻絕層）
# 但也必須將新的政治主張列為階段性行動綱領
# 必須立刻就醫
# 我們必須要正視貧苦大眾遭野心政客非法利用的問題
# 必須保有彈性
# 每一家債權銀行都必須遵守
# 政府並協助取得必須的土地
# 必須要肅貪法庭作出決定
# 自治條例草案是根據教育經費編列與管理法有關地方政府必須設置教育發展基金編列預算並制訂相關條例管理而來
# 主要必須藉由建築物本身的消防設備
# 必須出具董事會通過之增資承諾書

# %%
import re

text = "這是什麼？因為該批本土派立委必須以脫離國民黨為前提，他們會怎麼做？誰知道！但我們必須行動！這是事實。"

# 定义标点符号列表，用于匹配句子的开始和结束
punctuation = "。,，！？；"

# 正则表达式模式，用于提取含有"必須"的句子片段
pattern = f"([{punctuation}])([^{punctuation}]*必須[^{punctuation}]*)[{punctuation}]"

# 使用 re.finditer 来找到所有匹配的结果
matches = re.finditer(pattern, text)

# 打印所有找到的匹配片段
for match in matches:
    # 提取并打印匹配的句子片段，不包括前后的标点符号
    print("Matched segment:", match.group(2))
# Out:
# Matched segment: 因為該批本土派立委必須以脫離國民黨為前提
# Matched segment: 但我們必須行動
